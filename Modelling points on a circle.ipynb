# %%
import torch
from torch import nn
import numpy as np
import matplotlib.pyplot as plt

# %%
# Points on a circle are realted as follows x*2 + y*2 = r*2

F = lambda x: np.sqrt(25 - x**2)

# %%
xs = np.linspace(-5, 5, 100)
ys = F(xs)

# %%
plt.plot(xs, ys)

# %%
torch.set_printoptions(sci_mode=False)

# %%
layer = nn.Sequential(nn.Linear(1, 5), nn.ReLU(), nn.Linear(5, 1))

# %%
xs = torch.tensor(xs)
ys = torch.tensor(ys)

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt

# %%
# When bias is set to false in Linear layer a metrix multiplicaiton will happen
l = torch.nn.Linear(3, 3, bias=False)

# %%
inputs = torch.rand(2, 3)

# %%
l.weight
# Out:
# Parameter containing:
# tensor([[ 0.2978,  0.0041, -0.2989],
#         [ 0.4284, -0.1070, -0.1798],
#         [ 0.1986, -0.2883,  0.3881]], requires_grad=True)

# %%
inputs
# Out:
# tensor([[0.1614, 0.6789, 0.1436],
#         [0.7974, 0.6374, 0.3887]])

# %%
out1 = l(inputs)

# %%
out2 = inputs @ l.weight.T

# %%
# numbers in lacks
pat = [3807.57, 3005.50]
outstanding_shares = [335.91106,  320.82768]

for i in range(0,2):
    print("EPS: " + str(pat[i]/outstanding_shares[i]))
    



# 3807.57/67,318.1
# Out:
# EPS: 11.335053987207209
# EPS: 9.367957278499162

# %%
revenue = [67318.11, 40815.25]

# %%
for i in range(0, 2):
    print("PAT Margin: " + str(pat[i]/revenue[i]*100) + "%")
# Out:
# PAT Margin: 5.656085710071183%
# PAT Margin: 7.363669216775593%

# %%
finance_cost = [906.14, 267.50]
ebit = [3807.57 + 906.14 + 1677.78, 3005.50 + 267.50 + 1322.85]

for i in range(0, 2):
    print("Interest cov: " + str(ebit[i]/finance_cost[i]) + "%")
# Out:
# Interest cov: 7.0535347738760015%
# Interest cov: 17.180747663551404%

# %%
equity = [38413.20, 32898.34]

# %%
for i in range(0, 2):
    print("ROE: " + str(pat[i]/equity[i]))
# Out:
# ROE: 0.099121395770204
# ROE: 0.09135719309849677

# %%
print("ROE: " + str((pat[0]*2)/(equity[0] + equity[1])))
# Out:
# ROE: 0.10678692396770566

# %%
debts = [1115.49+6282.69, 1639.89 + 4205.00]

# %%
debts
# Out:
# [7398.179999999999, 5844.89]

# %%
for i in range(0, 2):
    print("D/E: " + str(debts[i]/equity[i]))
# Out:
# D/E: 0.19259473306051045
# D/E: 0.17766519526517147

# %%
avg_equity = (equity[0] + equity[1])/2

# %%
avg_equity
# Out:
# 35655.77

# %%
capital = avg_equity + debts[0]

# %%
capital
# Out:
# 43053.95

# %%
ROCE = ebit[0]/capital

# %%
ROCE
# Out:
# 0.1484530455393756

# %%
avg_assets = (63497.69 + 56782.29)/2

# %%
ROA = ebit[0]/avg_assets

# %%
ROA
# Out:
# 0.10627687167889452

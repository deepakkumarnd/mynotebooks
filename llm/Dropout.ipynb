# %%
import torch

# %%
sample = torch.ones(5, 5)

# %%
dropout = torch.nn.Dropout(0.1)

# %%
dropout(sample)
# Out:
# tensor([[1.1111, 1.1111, 1.1111, 1.1111, 1.1111],
#         [1.1111, 1.1111, 1.1111, 1.1111, 1.1111],
#         [1.1111, 1.1111, 1.1111, 1.1111, 1.1111],
#         [1.1111, 1.1111, 1.1111, 1.1111, 1.1111],
#         [1.1111, 1.1111, 1.1111, 1.1111, 1.1111]])

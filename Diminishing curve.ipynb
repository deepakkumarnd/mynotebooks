# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.concatenate([np.linspace(0, 30, 30),np.array([30] * 10), np.linspace(30, 60, 90), np.array([90]*30), np.linspace(60, 100, 100)])

# %%
x
# Out:
# array([  0.        ,   1.03448276,   2.06896552,   3.10344828,
#          4.13793103,   5.17241379,   6.20689655,   7.24137931,
#          8.27586207,   9.31034483,  10.34482759,  11.37931034,
#         12.4137931 ,  13.44827586,  14.48275862,  15.51724138,
#         16.55172414,  17.5862069 ,  18.62068966,  19.65517241,
#         20.68965517,  21.72413793,  22.75862069,  23.79310345,
#         24.82758621,  25.86206897,  26.89655172,  27.93103448,
#         28.96551724,  30.        ,  30.        ,  30.        ,
#         30.        ,  30.        ,  30.        ,  30.        ,
#         30.        ,  30.        ,  30.        ,  30.        ,
#         30.        ,  30.33707865,  30.6741573 ,  31.01123596,
#         31.34831461,  31.68539326,  32.02247191,  32.35955056,
#         32.69662921,  33.03370787,  33.37078652,  33.70786517,
#         34.04494382,  34.38202247,  34.71910112,  35.05617978,
#         35.39325843,  35.73033708,  36.06741573,  36.40449438,
# ...

# %%
t = np.array([t for t,_ in enumerate(x)])

# %%
g = 1.1

# %%
F = lambda xs, ts: xs**1.5 / (ts + 1)**0.5

# %%
y = F(x, t)

# %%
plt.plot(t, y)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 y.shape
#
# AttributeError: 'function' object has no attribute 'shape'

# %%
import spacy

# %%
from spacy import displacy

# %%
text = "Programming languages: Python, R, C++, Javascript."

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp(text)

# %%
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Programming languages:
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , R,
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     C++
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LANGUAGE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Javascript
# ...

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x17f20e080>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x17f20dc00>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x17f1184a0>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x17f0482c0>),
#  ('lemmatizer', <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x17f396300>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x17f1186d0>)]

# %%
nlp.remove_pipe('ner')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 nlp.remove_pipe('ner')
#
# File ~/Work/notebooks/jupyternev/lib/python3.10/site-packages/spacy/language.py:956, in Language.remove_pipe(self, name)
#     948 """Remove a component from the pipeline.
#     949
#     950 name (str): Name of the component to remove.
#    (...)
#     953 DOCS: https://spacy.io/api/language#remove_pipe
#     954 """
#     955 if name not in self.component_names:
# --> 956     raise ValueError(Errors.E001.format(name=name, opts=self.component_names))
#     957 removed = self._components.pop(self.component_names.index(name))
#     958 # We're only removing the component itself from the metas/configs here
#     959 # because factory may be used for something else
#
# ...

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x13069e200>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x13069e0e0>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x1306b93f0>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x1312c9780>),
#  ('lemmatizer', <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x127db6700>)]

# %%
displacy.render(nlp(text), style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Programming languages: Python, R, C++, Javascript.</div></span>

# %%
TRAIN_DATA = [
                ("Python, Ruby, Javascript", {"entities": [(0, 6, "PROGLANG"), (8,4, "PROGLANG"), (14,10)]}),
                ("Proficient in Python", {"entities": [(14,6, "PROGLANG")]})
            ]

# %%
TRAIN_DATA
# Out:
# [('Python, Ruby, Javascript',
#   {'entities': [(0, 6, 'PROGLANG'), (8, 4, 'PROGLANG'), (14, 10)]}),
#  ('Proficient in Python', {'entities': [(14, 6, 'PROGLANG')]})]

# %%
# !pip3 install pandas
# Out:
# ...
#   Using cached pandas-1.5.2-cp310-cp310-macosx_11_0_arm64.whl (10.8 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.4/499.4 kB 1.6 MB/s eta 0:00:001.1 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %%
COMPANIES = "./data/companies/companies.csv"

# %%
df = pd.read_csv(COMPANIES)

# %%
df.head()
# Out:
#                        NAME CATEGORY INDUSTRY TYPE  \
# 0          Haier Appliances     MNCs       Private
# 1                Suneratech     MNCs       Private
# 2                    HARMAN     MNCs       Private
# 3  Nucleus Software Exports     MNCs        Public
# 4                       ION     MNCs       Private
#
#                                            LOCATIONS  \
# 0   Pune(Ranjangaon) Greater Noida, Delhi / NCR Pune
# 1  Hyderabad/Secunderabad Hybrid - Hyderabad/Secu...
# 2  Hybrid - Hyderabad/Secunderabad, Pune, Chennai...
# 3                Hybrid - Noida Noida Noida, Chennai
# 4  Mumbai Bangalore/Bengaluru Noida, Bangalore/Be...
#
#                                                 TAGS            FOUNDED  \
# 0  Consumer Electronics & AppliancesElectronicsMa...  2004 (19 yrs old)
# 1      IT Services & ConsultingPrivateForeign MNCB2B  2005 (18 yrs old)
# 2  IT Services & ConsultingPrivateForeign MNCB2BA...  2001 (22 yrs old)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 535 entries, 0 to 534
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   NAME           533 non-null    object
#  1   CATEGORY       533 non-null    object
#  2   INDUSTRY TYPE  533 non-null    object
#  3   LOCATIONS      533 non-null    object
#  4   TAGS           533 non-null    object
#  5   FOUNDED        533 non-null    object
#  6   SIZE           533 non-null    object
#  7   ABOUT          533 non-null    object
#  8   LOGO URL       533 non-null    object
#  9   WEBSITE        179 non-null    object
#  10  HEADQUARTERS   124 non-null    object
# dtypes: object(11)
# memory usage: 46.1+ KB

# %%
df[["NAME", "TAGS"]].head(100)
# Out:
#                                NAME  \
# 0                  Haier Appliances
# 1                        Suneratech
# 2                            HARMAN
# 3          Nucleus Software Exports
# 4                               ION
# ..                              ...
# 95            Gadgeon Smart Systems
# 96             Cyber Infrastructure
# 97                       Bioclinica
# 98  World Resources Institute (WRI)
# 99                  Forbes Marshall
#
#                                                  TAGS
# 0   Consumer Electronics & AppliancesElectronicsMa...
# 1       IT Services & ConsultingPrivateForeign MNCB2B
# 2   IT Services & ConsultingPrivateForeign MNCB2BA...
# 3   Software ProductPublicIndian MNCB2BAmbitionBox...
# 4   IT Services & ConsultingHardware & NetworkingS...
# ..                                                ...
# 95      IT Services & ConsultingPrivateForeign MNCB2B
# 96      IT Services & ConsultingPrivateForeign MNCB2B
# ...

# %%
STACK_OVERFLOW_TAGS = "./data/stackoverflow/tags.csv"

# %%
STACK_OVERFLOW_QUESTIONS = "./data/stackoverflow/Questions.csv"

# %%
STACK_OVERFLOW_ANSWERS = "./data/stackoverflow/Answers.csv"

# %%
so_tags = pd.read_csv(STACK_OVERFLOW_TAGS)

# %%
so_tags.head(10)
# Out:
#     Id                    Tag
# 0   80                   flex
# 1   80         actionscript-3
# 2   80                    air
# 3   90                    svn
# 4   90            tortoisesvn
# 5   90                 branch
# 6   90  branching-and-merging
# 7  120                    sql
# 8  120                asp.net
# 9  120                sitemap

# %%
so_tags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3750994 entries, 0 to 3750993
# Data columns (total 2 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Id      int64
#  1   Tag     object
# dtypes: int64(1), object(1)
# memory usage: 57.2+ MB

# %%
len(so_tags)
# Out:
# 3750994

# %%
so_questions = pd.read_csv(STACK_OVERFLOW_QUESTIONS, encoding="ISO-8859-1", nrows=1000)

# %%
list(so_questions["Title"].tail(10))
# Out:
# ['Using Yahoo! Pipes',
#  'Connecting to Oracle using PHP',
#  'Trip time calculation in relational databases?',
#  'ORA-00161: transaction branch length 103 is illegal (maximum allowed 64',
#  'What alternatives are there to the MATLAB Editor?',
#  'How can I get the unique values of an array in .net?',
#  'What is the difference between TrueType fonts and Type-1 fonts?',
#  'How do I call a SQL Server stored procedure from PowerShell?',
#  'C++ does begin/end/rbegin/rend execute in constant time for std::set, std::map, etc?',
#  'Dynamically add CalendarExtender to Textbox subclass server control?']

# %%
so_questions
# Out:
#         Id  OwnerUserId          CreationDate            ClosedDate  Score  \
# 0       80         26.0  2008-08-01T13:57:07Z                   NaN     26
# 1       90         58.0  2008-08-01T14:41:24Z  2012-12-26T03:45:49Z    144
# 2      120         83.0  2008-08-01T15:50:08Z                   NaN     21
# 3      180    2089740.0  2008-08-01T18:42:19Z                   NaN     53
# 4      260         91.0  2008-08-01T23:22:08Z                   NaN     49
# ..     ...          ...                   ...                   ...    ...
# 995  83260      15928.0  2008-09-17T13:34:46Z                   NaN      3
# 996  83320      15719.0  2008-09-17T13:40:17Z                   NaN     13
# 997  83410      12767.0  2008-09-17T13:48:25Z                   NaN     26
# 998  83640       8123.0  2008-09-17T14:09:20Z                   NaN      3
# 999  83770      13583.0  2008-09-17T14:24:21Z                   NaN      2
#
#                                                  Title  \
# ...

# %%
# !ls data/stackoverflow
# Out:
# Answers.csv           Tags.csv
# Questions.csv         question_and_tags.csv

# %%
STACK_OVERFLOW_QUES_WITH_TAGS = "./data/stackoverflow/question_and_tags.csv"

# %%
data = pd.read_csv(STACK_OVERFLOW_QUES_WITH_TAGS, encoding="ISO-8859-1", nrows=1000)

# %%
data
# Out:
#                                                  title  \
# 0                  How to draw a stacked dotplot in R?
# 1    mysql select all records where a datetime fiel...
# 2               How to terminate windows phone 8.1 app
# 3    get current time in a specific country via jquery
# 4                        Configuring Tomcat to Use SSL
# ..                                                 ...
# 995         Using Python subprocess.call with crontab?
# 996               Updating Python for use with AWS CLI
# 997  Performing multiple database operations in a s...
# 998  Databinding a variable in C# to a textblock in...
# 999                          C++ OpenGL drawing a room
#
#                                       tags
# 0                                    ['r']
# 1                         ['php', 'mysql']
# 2                                   ['c#']
# 3                 ['javascript', 'jquery']
# 4                                 ['java']
# ...

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.13.0-cp310-cp310-macosx_12_0_arm64.whl (1.9 kB)
# Collecting tensorflow-macos==2.13.0
#   Downloading tensorflow_macos-2.13.0-cp310-cp310-macosx_12_0_arm64.whl (189.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.3/189.3 MB 13.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.15.0-cp310-cp310-macosx_11_0_arm64.whl (36 kB)
# Collecting h5py>=2.9.0
#   Downloading h5py-3.9.0-cp310-cp310-macosx_11_0_arm64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 12.7 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3
#   Downloading protobuf-4.23.4-cp37-abi3-macosx_10_9_universal2.whl (400 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.3/400.3 kB 12.3 MB/s eta 0:00:00
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 4.5 MB/s eta 0:00:00
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in ./jupyternev/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (4.4.0)
# Collecting flatbuffers>=23.1.21
#   Downloading flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Collecting keras<2.14,>=2.13.1
#   Downloading keras-2.13.1-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 18.7 MB/s eta 0:00:00m eta 0:00:010:01
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in ./jupyternev/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.24.1)
# Collecting absl-py>=1.0.0
#   Downloading absl_py-1.4.0-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.5/126.5 kB 8.7 MB/s eta 0:00:00
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting tensorflow-estimator<2.14,>=2.13.0
#   Downloading tensorflow_estimator-2.13.0-py2.py3-none-any.whl (440 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.8/440.8 kB 24.5 MB/s eta 0:00:00
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in ./jupyternev/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (65.6.3)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.56.0-cp310-cp310-macosx_12_0_universal2.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 22.6 MB/s eta 0:00:0031m24.0 MB/s eta 0:00:01
# Collecting libclang>=13.0.0
#   Downloading libclang-16.0.0-py2.py3-none-macosx_11_0_arm64.whl (24.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.3/24.3 MB 20.1 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting tensorboard<2.14,>=2.13
#   Downloading tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 25.6 MB/s eta 0:00:0031m27.6 MB/s eta 0:00:01
# Requirement already satisfied: packaging in ./jupyternev/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (22.0)
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: six>=1.12.0 in ./jupyternev/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.16.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./jupyternev/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.13.0->tensorflow) (0.38.4)
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.3.6-py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 15.5 MB/s eta 0:00:00
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.3-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.9/93.9 kB 6.3 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.1-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in ./jupyternev/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.28.1)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.22.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.8/181.8 kB 19.8 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: urllib3<2.0 in ./jupyternev/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (1.26.13)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 12.8 MB/s eta 0:00:00
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: certifi>=2017.4.17 in ./jupyternev/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in ./jupyternev/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in ./jupyternev/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.1.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./jupyternev/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.1.1)
# Collecting pyasn1<0.6.0,>=0.4.6
#   Downloading pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.9/83.9 kB 9.7 MB/s eta 0:00:00
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 21.2 MB/s eta 0:00:00
# Installing collected packages: libclang, flatbuffers, wrapt, werkzeug, termcolor, tensorflow-estimator, tensorboard-data-server, pyasn1, protobuf, opt-einsum, oauthlib, markdown, keras, h5py, grpcio, google-pasta, gast, cachetools, astunparse, absl-py, rsa, requests-oauthlib, pyasn1-modules, google-auth, google-auth-oauthlib, tensorboard, tensorflow-macos, tensorflow
# Successfully installed absl-py-1.4.0 astunparse-1.6.3 cachetools-5.3.1 flatbuffers-23.5.26 gast-0.4.0 google-auth-2.22.0 google-auth-oauthlib-1.0.0 google-pasta-0.2.0 grpcio-1.56.0 h5py-3.9.0 keras-2.13.1 libclang-16.0.0 markdown-3.4.3 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-4.23.4 pyasn1-0.5.0 pyasn1-modules-0.3.0 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.13.0 tensorboard-data-server-0.7.1 tensorflow-2.13.0 tensorflow-estimator-2.13.0 tensorflow-macos-2.13.0 termcolor-2.3.0 werkzeug-2.3.6 wrapt-1.15.0
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
num_classes = 10
input_shape = (28, 28, 1)

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# %%
x_train = x_train.astype("float32") / 255

# %%
x_test = x_test.astype("float32") / 255

# %%
x_train = np.expand_dims(x_train, -1)

# %%
x_test = np.expand_dims(x_test, -1)

# %%
y_train = keras.utils.to_categorical(y_train, num_classes)

# %%
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation="softmax"),
    ]
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 13, 13, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dropout (Dropout)           (None, 1600)              0
#
#  dense (Dense)               (None, 10)                16010
#
# =================================================================
# Total params: 34826 (136.04 KB)
# Trainable params: 34826 (136.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
batch_size = 128
epochs = 15

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# Out:
# Epoch 1/15
# 422/422 [==============================] - 7s 15ms/step - loss: 0.3620 - accuracy: 0.8885 - val_loss: 0.0833 - val_accuracy: 0.9785
# Epoch 2/15
# 422/422 [==============================] - 6s 15ms/step - loss: 0.1122 - accuracy: 0.9653 - val_loss: 0.0590 - val_accuracy: 0.9817
# Epoch 3/15
# 422/422 [==============================] - 6s 15ms/step - loss: 0.0859 - accuracy: 0.9738 - val_loss: 0.0479 - val_accuracy: 0.9885
# Epoch 4/15
# 422/422 [==============================] - 6s 15ms/step - loss: 0.0724 - accuracy: 0.9776 - val_loss: 0.0449 - val_accuracy: 0.9872
# Epoch 5/15
# 422/422 [==============================] - 6s 15ms/step - loss: 0.0637 - accuracy: 0.9799 - val_loss: 0.0364 - val_accuracy: 0.9907
# Epoch 6/15
# 422/422 [==============================] - 6s 15ms/step - loss: 0.0586 - accuracy: 0.9817 - val_loss: 0.0365 - val_accuracy: 0.9908
# Epoch 7/15
# 422/422 [==============================] - 6s 15ms/step - loss: 0.0513 - accuracy: 0.9836 - val_loss: 0.0342 - val_accuracy: 0.9905
# Epoch 8/15
# 422/422 [==============================] - 6s 15ms/step - loss: 0.0507 - accuracy: 0.9839 - val_loss: 0.0313 - val_accuracy: 0.9917
# Epoch 9/15
# 422/422 [==============================] - 6s 15ms/step - loss: 0.0451 - accuracy: 0.9864 - val_loss: 0.0314 - val_accuracy: 0.9918
# Epoch 10/15
# 422/422 [==============================] - 6s 15ms/step - loss: 0.0436 - accuracy: 0.9864 - val_loss: 0.0319 - val_accuracy: 0.9913
# Epoch 11/15
# 422/422 [==============================] - 6s 15ms/step - loss: 0.0405 - accuracy: 0.9866 - val_loss: 0.0298 - val_accuracy: 0.9928
# Epoch 12/15
# 422/422 [==============================] - 6s 15ms/step - loss: 0.0381 - accuracy: 0.9876 - val_loss: 0.0302 - val_accuracy: 0.9935
# Epoch 13/15
# 422/422 [==============================] - 6s 15ms/step - loss: 0.0382 - accuracy: 0.9878 - val_loss: 0.0286 - val_accuracy: 0.9928
# Epoch 14/15
# 422/422 [==============================] - 6s 15ms/step - loss: 0.0345 - accuracy: 0.9889 - val_loss: 0.0276 - val_accuracy: 0.9925
# Epoch 15/15
# 422/422 [==============================] - 6s 15ms/step - loss: 0.0340 - accuracy: 0.9889 - val_loss: 0.0285 - val_accuracy: 0.9928

# %%
score = model.evaluate(x_test, y_test, verbose=0)

# %%
score
# Out:
# [0.027306940406560898, 0.9909999966621399]

# %%
from keras import backend as k

# %%
k.backend()
# Out:
# 'tensorflow'

# %%
k.epsilon()
# Out:
# 1e-07

# %%
k.floatx()
# Out:
# 'float32'

# %%
import numpy as np

# %%
A = np.matrix("1 2 3; 4 5 6; 7 8 9")

# %%
A
# Out:
# matrix([[1, 2, 3],
#         [4, 5, 6],
#         [7, 8, 9]])

# %%
B = np.matrix("1 0 0; 0 1 0; 0 0 1")

# %%
B
# Out:
# matrix([[1, 0, 0],
#         [0, 1, 0],
#         [0, 0, 1]])

# %%
A @ B
# Out:
# matrix([[1, 2, 3],
#         [4, 5, 6],
#         [7, 8, 9]])

# %%
np.transpose(B)
# Out:
# matrix([[1, 0, 0],
#         [0, 1, 0],
#         [0, 0, 1]])

# %%
np.invert(B)
# Out:
# matrix([[-2, -1, -1],
#         [-1, -2, -1],
#         [-1, -1, -2]])

# %%
np.transpose(A)
# Out:
# matrix([[1, 4, 7],
#         [2, 5, 8],
#         [3, 6, 9]])

# %%
A @ np.transpose(A)
# Out:
# matrix([[ 14,  32,  50],
#         [ 32,  77, 122],
#         [ 50, 122, 194]])

# %%
C = np.matrix("0 0 1; 0 1 0; 1 0 0")

# %%
C
# Out:
# matrix([[0, 0, 1],
#         [0, 1, 0],
#         [1, 0, 0]])

# %%
A @ C
# Out:
# matrix([[3, 2, 1],
#         [6, 5, 4],
#         [9, 8, 7]])

# %%
np.transpose(A)
# Out:
# matrix([[1, 4, 7],
#         [2, 5, 8],
#         [3, 6, 9]])

# %%
A
# Out:
# matrix([[1, 2, 3],
#         [4, 5, 6],
#         [7, 8, 9]])

# %%
A.transpose()
# Out:
# matrix([[1, 4, 7],
#         [2, 5, 8],
#         [3, 6, 9]])

# %%
A.min()
# Out:
# 1

# %%
A.max()
# Out:
# 9

# %%
A.diagonal()
# Out:
# matrix([[1, 5, 9]])

# %%
A.getT()
# Out:
# matrix([[1, 4, 7],
#         [2, 5, 8],
#         [3, 6, 9]])

# %%
A
# Out:
# matrix([[1, 2, 3],
#         [4, 5, 6],
#         [7, 8, 9]])

# %%
A.view()
# Out:
# matrix([[1, 2, 3],
#         [4, 5, 6],
#         [7, 8, 9]])

# %%
A
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 A
#
# NameError: name 'A' is not defined

# %%
A.shape
# Out:
# (3, 3)

# %%
import pandas as pd

# %%
data = pd.read_csv("./data/worldcities.csv")

# %%
data
# Out:
#               city   city_ascii      lat      long      country  geo2  geo3  \
# 0            Tokyo        Tokyo  35.6839  139.7744        Japan    JP   JPN
# 1          Jakarta      Jakarta  -6.2146  106.8451    Indonesia    ID   IDN
# 2            Delhi        Delhi  28.6667   77.2167        India    IN   IND
# 3           Manila       Manila  14.6000  120.9833  Philippines    PH   PHL
# 4        São Paulo    Sao Paulo -23.5504  -46.6339       Brazil    BR   BRA
# ...            ...          ...      ...       ...          ...   ...   ...
# 42900       Tukchi       Tukchi  57.3670  139.5000       Russia    RU   RUS
# 42901        Numto        Numto  63.6667   71.3333       Russia    RU   RUS
# 42902         Nord         Nord  81.7166  -17.8000    Greenland    GL   GRL
# 42903  Timmiarmiut  Timmiarmiut  62.5333  -42.2167    Greenland    GL   GRL
# 42904      Nordvik      Nordvik  74.0165  111.5100       Russia    RU   RUS
#
# ...

# %%
# !pip install haversine
# !pip install matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 781.4 kB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.7/229.7 kB 369.3 kB/s eta 0:00:001m386.4 kB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 771.5 kB/s eta 0:00:000:00:01m eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.2/63.2 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 kB 766.1 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# ...
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: pip install --upgrade pip

# %%
import haversine as hs

# %%
data.columns
# Out:
# Index(['city', 'city_ascii', 'lat', 'long', 'country', 'geo2', 'geo3', 'skip1',
#        'skip2', 'population', 'id'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
data[["city", "population"]]
# Out:
#               city  population
# 0            Tokyo  39105000.0
# 1          Jakarta  35362000.0
# 2            Delhi  31870000.0
# 3           Manila  23971000.0
# 4        São Paulo  22495000.0
# ...            ...         ...
# 42900       Tukchi        10.0
# 42901        Numto        10.0
# 42902         Nord        10.0
# 42903  Timmiarmiut        10.0
# 42904      Nordvik         0.0
#
# [42905 rows x 2 columns]

# %%
df = data

# %%
df.columns
# Out:
# Index(['city', 'city_ascii', 'lat', 'long', 'country', 'geo2', 'geo3', 'skip1',
#        'skip2', 'population', 'id'],
#       dtype='object')

# %%
df.query("city == city_ascii")
# Out:
#               city   city_ascii      lat      long      country geo2 geo3  \
# 0            Tokyo        Tokyo  35.6839  139.7744        Japan   JP  JPN
# 1          Jakarta      Jakarta  -6.2146  106.8451    Indonesia   ID  IDN
# 2            Delhi        Delhi  28.6667   77.2167        India   IN  IND
# 3           Manila       Manila  14.6000  120.9833  Philippines   PH  PHL
# 5            Seoul        Seoul  37.5600  126.9900  South Korea   KR  KOR
# ...            ...          ...      ...       ...          ...  ...  ...
# 42900       Tukchi       Tukchi  57.3670  139.5000       Russia   RU  RUS
# 42901        Numto        Numto  63.6667   71.3333       Russia   RU  RUS
# 42902         Nord         Nord  81.7166  -17.8000    Greenland   GL  GRL
# 42903  Timmiarmiut  Timmiarmiut  62.5333  -42.2167    Greenland   GL  GRL
# 42904      Nordvik      Nordvik  74.0165  111.5100       Russia   RU  RUS
#
#                                           skip1    skip2  population  \
# ...

# %%
len(data[['city_ascii', 'country']])
# Out:
# 42905

# %%
len(pd.unique(data[['city_ascii', 'country']]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 len(pd.unique(data[['city_ascii', 'country']]))
#
# File ~/Work/notebooks/jupyternev/lib/python3.10/site-packages/pandas/core/algorithms.py:409, in unique(values)
#     315 def unique(values):
#     316     """
#     317     Return unique values based on a hash table.
#     318
#    (...)
#     407     array([('a', 'b'), ('b', 'a'), ('a', 'c')], dtype=object)
#     408     """
# --> 409     return unique_with_mask(values)
#
# File ~/Work/notebooks/jupyternev/lib/python3.10/site-packages/pandas/core/algorithms.py:414, in unique_with_mask(values, mask)
#     412 def unique_with_mask(values, mask: npt.NDArray[np.bool_] | None = None):
#     413     """See algorithms.unique for docs. Takes a mask for masked arrays."""
# --> 414     values = _ensure_arraylike(values)
# ...
